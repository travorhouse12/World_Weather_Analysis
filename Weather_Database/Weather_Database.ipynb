# %%
# Import the dependencies 
import pandas as pd 
from citipy import citipy
import numpy as np 
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = list(zip(lats, lngs))

# %%
# Add the latitudes and lonitudes to a list 
coordinates = lat_lngs

# %%
# Create a list to hold the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list. 
    if city not in cities: 
        cities.append(city)
# Print the city count to confirm sufficient count 
len(cities)
# Out:
# 754

# %%
# Starting URL for the Weather MAP API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8911124042f94923b39290c15c555954

# %%
# Create an empty list to hold the weather data. 
city_data = []
# Print the beginning of the logging. 
print("Beginning Data Retrieval   ")
print("---------------------------")

# Create counters. 
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes. 
    if (i % 50 == 0 and i > 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city. 
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city. 
    print(f"Prcessing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count. 
    record_count += 1

# Run an API request for each of the cities. 
    try:
        # Pare the JSON and retrieve data. 
        city_weather = requests.get(city_url).json()
        # Parse out the needed data. 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list. 
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error occurs, skip the city. 
    except:
        print("City not found. Skipping....")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Prcessing Record 1 of Set 1 | mataura
# Prcessing Record 2 of Set 1 | tucuman
# Prcessing Record 3 of Set 1 | barentsburg
# City not found. Skipping....
# Prcessing Record 4 of Set 1 | meulaboh
# Prcessing Record 5 of Set 1 | aberdeen
# Prcessing Record 6 of Set 1 | tiksi
# Prcessing Record 7 of Set 1 | ganzhou
# Prcessing Record 8 of Set 1 | vila franca do campo
# Prcessing Record 9 of Set 1 | denpasar
# Prcessing Record 10 of Set 1 | rikitea
# Prcessing Record 11 of Set 1 | altamira
# Prcessing Record 12 of Set 1 | tukrah
# Prcessing Record 13 of Set 1 | rawson
# Prcessing Record 14 of Set 1 | vaitupu
# City not found. Skipping....
# Prcessing Record 15 of Set 1 | huanuni
# Prcessing Record 16 of Set 1 | birkeland
# Prcessing Record 17 of Set 1 | mar del plata
# Prcessing Record 18 of Set 1 | touros
# Prcessing Record 19 of Set 1 | albany
# Prcessing Record 20 of Set 1 | tuktoyaktuk
# Prcessing Record 21 of Set 1 | taolanaro
# City not found. Skipping....
# Prcessing Record 22 of Set 1 | pevek
# Prcessing Record 23 of Set 1 | kutum
# Prcessing Record 24 of Set 1 | namibe
# Prcessing Record 25 of Set 1 | kavaratti
# Prcessing Record 26 of Set 1 | longyearbyen
# Prcessing Record 27 of Set 1 | jamestown
# Prcessing Record 28 of Set 1 | port alfred
# Prcessing Record 29 of Set 1 | abiy adi
# City not found. Skipping....
# Prcessing Record 30 of Set 1 | lebu
# Prcessing Record 31 of Set 1 | busselton
# Prcessing Record 32 of Set 1 | louisbourg
# City not found. Skipping....
# Prcessing Record 33 of Set 1 | naze
# Prcessing Record 34 of Set 1 | carnarvon
# Prcessing Record 35 of Set 1 | bathsheba
# Prcessing Record 36 of Set 1 | ushuaia
# Prcessing Record 37 of Set 1 | nikolskoye
# Prcessing Record 38 of Set 1 | severo-kurilsk
# Prcessing Record 39 of Set 1 | namatanai
# Prcessing Record 40 of Set 1 | pryozerne
# Prcessing Record 41 of Set 1 | puerto maldonado
# Prcessing Record 42 of Set 1 | niagara falls
# Prcessing Record 43 of Set 1 | yellowknife
# Prcessing Record 44 of Set 1 | kapaa
# Prcessing Record 45 of Set 1 | georgetown
# Prcessing Record 46 of Set 1 | kavieng
# Prcessing Record 47 of Set 1 | fukue
# Prcessing Record 48 of Set 1 | tsihombe
# City not found. Skipping....
# Prcessing Record 49 of Set 1 | cabo san lucas
# Prcessing Record 50 of Set 1 | belushya guba
# City not found. Skipping....
# Prcessing Record 51 of Set 1 | san patricio
# Prcessing Record 52 of Set 1 | castro
# Prcessing Record 53 of Set 1 | lompoc
# Prcessing Record 54 of Set 1 | wewak
# Prcessing Record 55 of Set 1 | butaritari
# Prcessing Record 56 of Set 1 | vila velha
# Prcessing Record 57 of Set 1 | gerash
# Prcessing Record 58 of Set 1 | wanning
# Prcessing Record 59 of Set 1 | bundaberg
# Prcessing Record 60 of Set 1 | dikson
# Prcessing Record 61 of Set 1 | tasiilaq
# Prcessing Record 62 of Set 1 | mys shmidta
# City not found. Skipping....
# Prcessing Record 63 of Set 1 | cape town
# Prcessing Record 64 of Set 1 | grindavik
# Prcessing Record 65 of Set 1 | broome
# Prcessing Record 66 of Set 1 | norman wells
# Prcessing Record 67 of Set 1 | rheine
# Prcessing Record 68 of Set 1 | sendhwa
# Prcessing Record 69 of Set 1 | airai
# Prcessing Record 70 of Set 1 | nelson bay
# Prcessing Record 71 of Set 1 | fort nelson
# Prcessing Record 72 of Set 1 | ancud
# Prcessing Record 73 of Set 1 | saryshagan
# City not found. Skipping....
# Prcessing Record 74 of Set 1 | ahipara
# Prcessing Record 75 of Set 1 | arraial do cabo
# Prcessing Record 76 of Set 1 | hermanus
# Prcessing Record 77 of Set 1 | qaanaaq
# Prcessing Record 78 of Set 1 | saint-philippe
# Prcessing Record 79 of Set 1 | illoqqortoormiut
# City not found. Skipping....
# Prcessing Record 80 of Set 1 | hobart
# Prcessing Record 81 of Set 1 | bredasdorp
# Prcessing Record 82 of Set 1 | buffalo
# Prcessing Record 83 of Set 1 | dingle
# Prcessing Record 84 of Set 1 | chuy
# Prcessing Record 85 of Set 1 | dhidhdhoo
# Prcessing Record 86 of Set 1 | clyde river
# Prcessing Record 87 of Set 1 | vaini
# Prcessing Record 88 of Set 1 | tocopilla
# Prcessing Record 89 of Set 1 | havre-saint-pierre
# Prcessing Record 90 of Set 1 | punta arenas
# Prcessing Record 91 of Set 1 | cherskiy
# Prcessing Record 92 of Set 1 | fukuma
# Prcessing Record 93 of Set 1 | kodiak
# Prcessing Record 94 of Set 1 | santa quiteria
# Prcessing Record 95 of Set 1 | peleduy
# Prcessing Record 96 of Set 1 | rocha
# Prcessing Record 97 of Set 1 | karakendzha
# City not found. Skipping....
# Prcessing Record 98 of Set 1 | guaraniacu
# Prcessing Record 99 of Set 1 | magalia
# Prcessing Record 100 of Set 1 | tiznit
# Prcessing Record 1 of Set 2 | esperance
# Prcessing Record 2 of Set 2 | puerto del rosario
# Prcessing Record 3 of Set 2 | palabuhanratu
# City not found. Skipping....
# Prcessing Record 4 of Set 2 | nanortalik
# Prcessing Record 5 of Set 2 | souillac
# Prcessing Record 6 of Set 2 | cuautepec
# Prcessing Record 7 of Set 2 | guerrero negro
# Prcessing Record 8 of Set 2 | bien hoa
# Prcessing Record 9 of Set 2 | kruisfontein
# Prcessing Record 10 of Set 2 | bara
# Prcessing Record 11 of Set 2 | chupa
# Prcessing Record 12 of Set 2 | ribeira grande
# Prcessing Record 13 of Set 2 | khormuj
# City not found. Skipping....
# Prcessing Record 14 of Set 2 | qasigiannguit
# Prcessing Record 15 of Set 2 | vestmannaeyjar
# Prcessing Record 16 of Set 2 | borgomanero
# Prcessing Record 17 of Set 2 | luena
# Prcessing Record 18 of Set 2 | santa maria da vitoria
# Prcessing Record 19 of Set 2 | torbay
# Prcessing Record 20 of Set 2 | new norfolk
# Prcessing Record 21 of Set 2 | haines junction
# Prcessing Record 22 of Set 2 | hithadhoo
# Prcessing Record 23 of Set 2 | sakakah
# Prcessing Record 24 of Set 2 | troitskoye
# Prcessing Record 25 of Set 2 | waipawa
# Prcessing Record 26 of Set 2 | ouadda
# Prcessing Record 27 of Set 2 | yumen
# Prcessing Record 28 of Set 2 | bluff
# Prcessing Record 29 of Set 2 | talara
# Prcessing Record 30 of Set 2 | yelkhovka
# Prcessing Record 31 of Set 2 | bambous virieux
# Prcessing Record 32 of Set 2 | nome
# Prcessing Record 33 of Set 2 | makakilo city
# Prcessing Record 34 of Set 2 | dumas
# Prcessing Record 35 of Set 2 | thompson
# Prcessing Record 36 of Set 2 | vao
# Prcessing Record 37 of Set 2 | kawalu
# Prcessing Record 38 of Set 2 | mersing
# Prcessing Record 39 of Set 2 | constitucion
# Prcessing Record 40 of Set 2 | suez
# Prcessing Record 41 of Set 2 | necochea
# Prcessing Record 42 of Set 2 | tougan
# Prcessing Record 43 of Set 2 | hilo
# Prcessing Record 44 of Set 2 | fort-shevchenko
# Prcessing Record 45 of Set 2 | lorengau
# Prcessing Record 46 of Set 2 | magadan
# Prcessing Record 47 of Set 2 | tuatapere
# Prcessing Record 48 of Set 2 | saint-joseph
# Prcessing Record 49 of Set 2 | verkhoyansk
# Prcessing Record 50 of Set 2 | batemans bay
# Prcessing Record 1 of Set 3 | wadi musa
# Prcessing Record 2 of Set 3 | zhigansk
# Prcessing Record 3 of Set 3 | dharchula
# Prcessing Record 4 of Set 3 | rockland
# Prcessing Record 5 of Set 3 | egvekinot
# Prcessing Record 6 of Set 3 | tazovskiy
# Prcessing Record 7 of Set 3 | shenzhen
# Prcessing Record 8 of Set 3 | berlevag
# Prcessing Record 9 of Set 3 | luau
# Prcessing Record 10 of Set 3 | avarua
# Prcessing Record 11 of Set 3 | mehamn
# Prcessing Record 12 of Set 3 | beringovskiy
# Prcessing Record 13 of Set 3 | kaitangata
# Prcessing Record 14 of Set 3 | komsomolskiy
# Prcessing Record 15 of Set 3 | santa isabel
# Prcessing Record 16 of Set 3 | lamu
# Prcessing Record 17 of Set 3 | ponta do sol
# Prcessing Record 18 of Set 3 | east london
# Prcessing Record 19 of Set 3 | faya
# Prcessing Record 20 of Set 3 | bengkulu
# Prcessing Record 21 of Set 3 | grand-santi
# Prcessing Record 22 of Set 3 | chapais
# Prcessing Record 23 of Set 3 | chokurdakh
# Prcessing Record 24 of Set 3 | bethel
# Prcessing Record 25 of Set 3 | atuona
# Prcessing Record 26 of Set 3 | ozernovskiy
# Prcessing Record 27 of Set 3 | saint marys
# Prcessing Record 28 of Set 3 | pisco
# Prcessing Record 29 of Set 3 | coolum beach
# Prcessing Record 30 of Set 3 | coquimbo
# Prcessing Record 31 of Set 3 | lagoa
# Prcessing Record 32 of Set 3 | fort saint james
# Prcessing Record 33 of Set 3 | khatanga
# Prcessing Record 34 of Set 3 | muisne
# Prcessing Record 35 of Set 3 | sept-iles
# Prcessing Record 36 of Set 3 | kirakira
# Prcessing Record 37 of Set 3 | fairbanks
# Prcessing Record 38 of Set 3 | oksfjord
# Prcessing Record 39 of Set 3 | kismayo
# Prcessing Record 40 of Set 3 | portland
# Prcessing Record 41 of Set 3 | cayenne
# Prcessing Record 42 of Set 3 | chama
# Prcessing Record 43 of Set 3 | bandarbeyla
# Prcessing Record 44 of Set 3 | amderma
# City not found. Skipping....
# Prcessing Record 45 of Set 3 | sitka
# Prcessing Record 46 of Set 3 | okha
# Prcessing Record 47 of Set 3 | attawapiskat
# City not found. Skipping....
# Prcessing Record 48 of Set 3 | simpang
# Prcessing Record 49 of Set 3 | florence
# Prcessing Record 50 of Set 3 | fortuna
# Prcessing Record 1 of Set 4 | barcelona
# Prcessing Record 2 of Set 4 | dauphin
# Prcessing Record 3 of Set 4 | sao filipe
# Prcessing Record 4 of Set 4 | marshall
# Prcessing Record 5 of Set 4 | pangoa
# Prcessing Record 6 of Set 4 | saskylakh
# Prcessing Record 7 of Set 4 | omboue
# Prcessing Record 8 of Set 4 | shu
# Prcessing Record 9 of Set 4 | itarema
# Prcessing Record 10 of Set 4 | sistranda
# Prcessing Record 11 of Set 4 | puerto ayora
# Prcessing Record 12 of Set 4 | puri
# Prcessing Record 13 of Set 4 | pokosnoye
# Prcessing Record 14 of Set 4 | banjar
# Prcessing Record 15 of Set 4 | brazzaville
# Prcessing Record 16 of Set 4 | cidreira
# Prcessing Record 17 of Set 4 | kiama
# Prcessing Record 18 of Set 4 | san ignacio
# Prcessing Record 19 of Set 4 | dunda
# Prcessing Record 20 of Set 4 | maputo
# Prcessing Record 21 of Set 4 | chapada dos guimaraes
# Prcessing Record 22 of Set 4 | itaqui
# Prcessing Record 23 of Set 4 | anadyr
# Prcessing Record 24 of Set 4 | marovoay
# Prcessing Record 25 of Set 4 | havelock
# Prcessing Record 26 of Set 4 | ovsyanka
# Prcessing Record 27 of Set 4 | devils lake
# Prcessing Record 28 of Set 4 | moyale
# Prcessing Record 29 of Set 4 | goderich
# Prcessing Record 30 of Set 4 | san juan
# Prcessing Record 31 of Set 4 | bocaiuva
# Prcessing Record 32 of Set 4 | grand river south east
# City not found. Skipping....
# Prcessing Record 33 of Set 4 | moranbah
# Prcessing Record 34 of Set 4 | villarrica
# Prcessing Record 35 of Set 4 | pioner
# Prcessing Record 36 of Set 4 | ampanihy
# Prcessing Record 37 of Set 4 | dinagat
# Prcessing Record 38 of Set 4 | kencong
# Prcessing Record 39 of Set 4 | palmerston
# Prcessing Record 40 of Set 4 | abhar
# Prcessing Record 41 of Set 4 | nizwa
# Prcessing Record 42 of Set 4 | comodoro rivadavia
# Prcessing Record 43 of Set 4 | cordoba
# Prcessing Record 44 of Set 4 | chicama
# Prcessing Record 45 of Set 4 | qui nhon
# Prcessing Record 46 of Set 4 | gimli
# Prcessing Record 47 of Set 4 | svetlogorsk
# Prcessing Record 48 of Set 4 | kisanga
# Prcessing Record 49 of Set 4 | sabzevar
# Prcessing Record 50 of Set 4 | maragogi
# Prcessing Record 1 of Set 5 | san quintin
# Prcessing Record 2 of Set 5 | aykhal
# Prcessing Record 3 of Set 5 | port hardy
# Prcessing Record 4 of Set 5 | prabumulih
# Prcessing Record 5 of Set 5 | alice springs
# Prcessing Record 6 of Set 5 | katsuura
# Prcessing Record 7 of Set 5 | carutapera
# Prcessing Record 8 of Set 5 | nago
# Prcessing Record 9 of Set 5 | korla
# Prcessing Record 10 of Set 5 | saint george
# Prcessing Record 11 of Set 5 | narsaq
# Prcessing Record 12 of Set 5 | ketchikan
# Prcessing Record 13 of Set 5 | olafsvik
# Prcessing Record 14 of Set 5 | nautla
# Prcessing Record 15 of Set 5 | coahuayana
# Prcessing Record 16 of Set 5 | faanui
# Prcessing Record 17 of Set 5 | iqaluit
# Prcessing Record 18 of Set 5 | geraldton
# Prcessing Record 19 of Set 5 | daska
# Prcessing Record 20 of Set 5 | rio bueno
# Prcessing Record 21 of Set 5 | waren
# Prcessing Record 22 of Set 5 | mudgee
# Prcessing Record 23 of Set 5 | kenosha
# Prcessing Record 24 of Set 5 | venice
# Prcessing Record 25 of Set 5 | genova
# Prcessing Record 26 of Set 5 | wau
# Prcessing Record 27 of Set 5 | oga
# Prcessing Record 28 of Set 5 | dodge city
# Prcessing Record 29 of Set 5 | camacha
# Prcessing Record 30 of Set 5 | nishihara
# Prcessing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping....
# Prcessing Record 32 of Set 5 | kloulklubed
# Prcessing Record 33 of Set 5 | ahero
# Prcessing Record 34 of Set 5 | tawkar
# City not found. Skipping....
# Prcessing Record 35 of Set 5 | nantucket
# Prcessing Record 36 of Set 5 | salym
# Prcessing Record 37 of Set 5 | sur
# Prcessing Record 38 of Set 5 | gao
# Prcessing Record 39 of Set 5 | banepa
# Prcessing Record 40 of Set 5 | betioky
# Prcessing Record 41 of Set 5 | saryagash
# Prcessing Record 42 of Set 5 | kendari
# Prcessing Record 43 of Set 5 | port lincoln
# Prcessing Record 44 of Set 5 | los llanos de aridane
# Prcessing Record 45 of Set 5 | robertson
# Prcessing Record 46 of Set 5 | samusu
# City not found. Skipping....
# Prcessing Record 47 of Set 5 | bur gabo
# City not found. Skipping....
# Prcessing Record 48 of Set 5 | mahebourg
# Prcessing Record 49 of Set 5 | kapit
# Prcessing Record 50 of Set 5 | camocim
# Prcessing Record 1 of Set 6 | saint-georges
# Prcessing Record 2 of Set 6 | skalistyy
# City not found. Skipping....
# Prcessing Record 3 of Set 6 | jasdan
# Prcessing Record 4 of Set 6 | tarudant
# City not found. Skipping....
# Prcessing Record 5 of Set 6 | henties bay
# Prcessing Record 6 of Set 6 | puerto escondido
# Prcessing Record 7 of Set 6 | marquette
# Prcessing Record 8 of Set 6 | araouane
# Prcessing Record 9 of Set 6 | neepawa
# Prcessing Record 10 of Set 6 | tevaitoa
# Prcessing Record 11 of Set 6 | lucapa
# Prcessing Record 12 of Set 6 | juneau
# Prcessing Record 13 of Set 6 | hami
# Prcessing Record 14 of Set 6 | manoel urbano
# Prcessing Record 15 of Set 6 | kashi
# Prcessing Record 16 of Set 6 | sobolevo
# Prcessing Record 17 of Set 6 | lodeynoye pole
# Prcessing Record 18 of Set 6 | yerbogachen
# Prcessing Record 19 of Set 6 | dubna
# Prcessing Record 20 of Set 6 | kalmunai
# Prcessing Record 21 of Set 6 | ksenyevka
# City not found. Skipping....
# Prcessing Record 22 of Set 6 | ostrovnoy
# Prcessing Record 23 of Set 6 | gorontalo
# Prcessing Record 24 of Set 6 | vostok
# Prcessing Record 25 of Set 6 | lavrentiya
# Prcessing Record 26 of Set 6 | patitirion
# Prcessing Record 27 of Set 6 | alekseyevka
# Prcessing Record 28 of Set 6 | zyryanovsk
# Prcessing Record 29 of Set 6 | jutai
# Prcessing Record 30 of Set 6 | sioux lookout
# Prcessing Record 31 of Set 6 | parrita
# Prcessing Record 32 of Set 6 | marcona
# City not found. Skipping....
# Prcessing Record 33 of Set 6 | buala
# Prcessing Record 34 of Set 6 | te anau
# Prcessing Record 35 of Set 6 | karkaralinsk
# City not found. Skipping....
# Prcessing Record 36 of Set 6 | upernavik
# Prcessing Record 37 of Set 6 | jiangyou
# Prcessing Record 38 of Set 6 | cape coast
# Prcessing Record 39 of Set 6 | hamilton
# Prcessing Record 40 of Set 6 | hasaki
# Prcessing Record 41 of Set 6 | barrow
# Prcessing Record 42 of Set 6 | balkanabat
# Prcessing Record 43 of Set 6 | great yarmouth
# Prcessing Record 44 of Set 6 | waitati
# Prcessing Record 45 of Set 6 | sao felix do xingu
# Prcessing Record 46 of Set 6 | husavik
# Prcessing Record 47 of Set 6 | saiha
# Prcessing Record 48 of Set 6 | pangody
# Prcessing Record 49 of Set 6 | soe
# Prcessing Record 50 of Set 6 | naugachhia
# Prcessing Record 1 of Set 7 | chulym
# Prcessing Record 2 of Set 7 | acari
# Prcessing Record 3 of Set 7 | suntar
# Prcessing Record 4 of Set 7 | christchurch
# Prcessing Record 5 of Set 7 | flinders
# Prcessing Record 6 of Set 7 | provideniya
# Prcessing Record 7 of Set 7 | poum
# Prcessing Record 8 of Set 7 | itaituba
# Prcessing Record 9 of Set 7 | mahbubabad
# Prcessing Record 10 of Set 7 | avera
# Prcessing Record 11 of Set 7 | holalkere
# Prcessing Record 12 of Set 7 | menongue
# Prcessing Record 13 of Set 7 | sundumbili
# Prcessing Record 14 of Set 7 | warqla
# City not found. Skipping....
# Prcessing Record 15 of Set 7 | codrington
# Prcessing Record 16 of Set 7 | port augusta
# Prcessing Record 17 of Set 7 | boca do acre
# Prcessing Record 18 of Set 7 | hobyo
# Prcessing Record 19 of Set 7 | saleaula
# City not found. Skipping....
# Prcessing Record 20 of Set 7 | alta floresta
# Prcessing Record 21 of Set 7 | basco
# Prcessing Record 22 of Set 7 | nikolsk
# Prcessing Record 23 of Set 7 | high rock
# Prcessing Record 24 of Set 7 | gold coast
# Prcessing Record 25 of Set 7 | caravelas
# Prcessing Record 26 of Set 7 | tiarei
# Prcessing Record 27 of Set 7 | corovode
# Prcessing Record 28 of Set 7 | strezhevoy
# Prcessing Record 29 of Set 7 | ende
# Prcessing Record 30 of Set 7 | manggar
# Prcessing Record 31 of Set 7 | gizo
# Prcessing Record 32 of Set 7 | lively
# Prcessing Record 33 of Set 7 | tshikapa
# Prcessing Record 34 of Set 7 | bocas del toro
# Prcessing Record 35 of Set 7 | oktyabrskiy
# Prcessing Record 36 of Set 7 | goldap
# Prcessing Record 37 of Set 7 | doha
# Prcessing Record 38 of Set 7 | senneterre
# Prcessing Record 39 of Set 7 | jizan
# Prcessing Record 40 of Set 7 | chifeng
# Prcessing Record 41 of Set 7 | langsa
# Prcessing Record 42 of Set 7 | pahrump
# Prcessing Record 43 of Set 7 | chivilcoy
# Prcessing Record 44 of Set 7 | kondagaon
# Prcessing Record 45 of Set 7 | kahului
# Prcessing Record 46 of Set 7 | marzuq
# Prcessing Record 47 of Set 7 | darhan
# Prcessing Record 48 of Set 7 | alofi
# Prcessing Record 49 of Set 7 | amahai
# Prcessing Record 50 of Set 7 | madang
# Prcessing Record 1 of Set 8 | hofn
# Prcessing Record 2 of Set 8 | sorong
# Prcessing Record 3 of Set 8 | yeppoon
# Prcessing Record 4 of Set 8 | hambantota
# Prcessing Record 5 of Set 8 | shakawe
# Prcessing Record 6 of Set 8 | burnie
# Prcessing Record 7 of Set 8 | ngukurr
# City not found. Skipping....
# Prcessing Record 8 of Set 8 | diego de almagro
# Prcessing Record 9 of Set 8 | tortosa
# Prcessing Record 10 of Set 8 | songea
# Prcessing Record 11 of Set 8 | umm lajj
# Prcessing Record 12 of Set 8 | nalut
# Prcessing Record 13 of Set 8 | the valley
# Prcessing Record 14 of Set 8 | qiyang
# Prcessing Record 15 of Set 8 | nemuro
# Prcessing Record 16 of Set 8 | bilma
# Prcessing Record 17 of Set 8 | wattegama
# Prcessing Record 18 of Set 8 | uk
# City not found. Skipping....
# Prcessing Record 19 of Set 8 | awjilah
# Prcessing Record 20 of Set 8 | nguiu
# City not found. Skipping....
# Prcessing Record 21 of Set 8 | luderitz
# Prcessing Record 22 of Set 8 | moose factory
# Prcessing Record 23 of Set 8 | pyay
# Prcessing Record 24 of Set 8 | gudiyattam
# City not found. Skipping....
# Prcessing Record 25 of Set 8 | ambilobe
# Prcessing Record 26 of Set 8 | manyana
# Prcessing Record 27 of Set 8 | mexico
# Prcessing Record 28 of Set 8 | ukiah
# Prcessing Record 29 of Set 8 | tubruq
# City not found. Skipping....
# Prcessing Record 30 of Set 8 | vigeland
# Prcessing Record 31 of Set 8 | kirchhundem
# Prcessing Record 32 of Set 8 | kutulik
# Prcessing Record 33 of Set 8 | kaeo
# Prcessing Record 34 of Set 8 | san pedro de lloc
# Prcessing Record 35 of Set 8 | stykkisholmur
# Prcessing Record 36 of Set 8 | itoman
# Prcessing Record 37 of Set 8 | beloha
# Prcessing Record 38 of Set 8 | alta
# Prcessing Record 39 of Set 8 | srednekolymsk
# Prcessing Record 40 of Set 8 | rakhya
# City not found. Skipping....
# Prcessing Record 41 of Set 8 | unity
# Prcessing Record 42 of Set 8 | baculin
# Prcessing Record 43 of Set 8 | port elizabeth
# Prcessing Record 44 of Set 8 | konosha
# Prcessing Record 45 of Set 8 | saint-pierre
# Prcessing Record 46 of Set 8 | gawler
# Prcessing Record 47 of Set 8 | la palma
# Prcessing Record 48 of Set 8 | shibetsu
# Prcessing Record 49 of Set 8 | ransang
# Prcessing Record 50 of Set 8 | vanimo
# Prcessing Record 1 of Set 9 | plouzane
# Prcessing Record 2 of Set 9 | toungoo
# City not found. Skipping....
# Prcessing Record 3 of Set 9 | vardo
# Prcessing Record 4 of Set 9 | talnakh
# Prcessing Record 5 of Set 9 | tarlisua
# City not found. Skipping....
# Prcessing Record 6 of Set 9 | newport
# Prcessing Record 7 of Set 9 | bokspits
# City not found. Skipping....
# Prcessing Record 8 of Set 9 | kayerkan
# Prcessing Record 9 of Set 9 | mareeba
# Prcessing Record 10 of Set 9 | harper
# Prcessing Record 11 of Set 9 | atherton
# Prcessing Record 12 of Set 9 | hualmay
# Prcessing Record 13 of Set 9 | zheleznodorozhnyy
# Prcessing Record 14 of Set 9 | yining
# Prcessing Record 15 of Set 9 | batsfjord
# Prcessing Record 16 of Set 9 | urumqi
# Prcessing Record 17 of Set 9 | lubango
# Prcessing Record 18 of Set 9 | rio branco
# Prcessing Record 19 of Set 9 | san antonio
# Prcessing Record 20 of Set 9 | heishan
# Prcessing Record 21 of Set 9 | dwarka
# Prcessing Record 22 of Set 9 | moron
# Prcessing Record 23 of Set 9 | axim
# Prcessing Record 24 of Set 9 | areosa
# Prcessing Record 25 of Set 9 | makat
# Prcessing Record 26 of Set 9 | altay
# Prcessing Record 27 of Set 9 | kodinsk
# Prcessing Record 28 of Set 9 | tommot
# Prcessing Record 29 of Set 9 | saint anthony
# Prcessing Record 30 of Set 9 | belyy yar
# Prcessing Record 31 of Set 9 | prince rupert
# Prcessing Record 32 of Set 9 | birao
# Prcessing Record 33 of Set 9 | tura
# Prcessing Record 34 of Set 9 | catamarca
# Prcessing Record 35 of Set 9 | koshurnikovo
# Prcessing Record 36 of Set 9 | ambodifototra
# City not found. Skipping....
# Prcessing Record 37 of Set 9 | leningradskiy
# Prcessing Record 38 of Set 9 | bendigo
# Prcessing Record 39 of Set 9 | gazanjyk
# Prcessing Record 40 of Set 9 | kokologo
# Prcessing Record 41 of Set 9 | whitehorse
# Prcessing Record 42 of Set 9 | sayyan
# Prcessing Record 43 of Set 9 | san vicente
# Prcessing Record 44 of Set 9 | khonuu
# City not found. Skipping....
# Prcessing Record 45 of Set 9 | atbasar
# Prcessing Record 46 of Set 9 | mugur-aksy
# Prcessing Record 47 of Set 9 | pacific grove
# Prcessing Record 48 of Set 9 | cockburn town
# Prcessing Record 49 of Set 9 | akureyri
# Prcessing Record 50 of Set 9 | kargasok
# Prcessing Record 1 of Set 10 | kailua
# Prcessing Record 2 of Set 10 | valparaiso
# Prcessing Record 3 of Set 10 | palmer
# Prcessing Record 4 of Set 10 | danane
# Prcessing Record 5 of Set 10 | tete
# Prcessing Record 6 of Set 10 | diamantino
# Prcessing Record 7 of Set 10 | karratha
# Prcessing Record 8 of Set 10 | kenai
# Prcessing Record 9 of Set 10 | broken hill
# Prcessing Record 10 of Set 10 | nhulunbuy
# Prcessing Record 11 of Set 10 | manono
# Prcessing Record 12 of Set 10 | saint-louis
# Prcessing Record 13 of Set 10 | sentyabrskiy
# City not found. Skipping....
# Prcessing Record 14 of Set 10 | bolungarvik
# City not found. Skipping....
# Prcessing Record 15 of Set 10 | kulhudhuffushi
# Prcessing Record 16 of Set 10 | saint-francois
# Prcessing Record 17 of Set 10 | santa lucia
# Prcessing Record 18 of Set 10 | umzimvubu
# City not found. Skipping....
# Prcessing Record 19 of Set 10 | salinopolis
# Prcessing Record 20 of Set 10 | pasighat
# Prcessing Record 21 of Set 10 | pinyug
# Prcessing Record 22 of Set 10 | chico
# Prcessing Record 23 of Set 10 | krasnoselkup
# Prcessing Record 24 of Set 10 | zhezkazgan
# Prcessing Record 25 of Set 10 | dubenskiy
# City not found. Skipping....
# Prcessing Record 26 of Set 10 | tual
# Prcessing Record 27 of Set 10 | vacha
# Prcessing Record 28 of Set 10 | zitsa
# Prcessing Record 29 of Set 10 | bintulu
# Prcessing Record 30 of Set 10 | victoria
# Prcessing Record 31 of Set 10 | sangar
# Prcessing Record 32 of Set 10 | tananger
# Prcessing Record 33 of Set 10 | fuling
# Prcessing Record 34 of Set 10 | khash
# Prcessing Record 35 of Set 10 | casper
# Prcessing Record 36 of Set 10 | leh
# Prcessing Record 37 of Set 10 | isangel
# Prcessing Record 38 of Set 10 | ixtapa
# Prcessing Record 39 of Set 10 | chippewa falls
# Prcessing Record 40 of Set 10 | vanavara
# Prcessing Record 41 of Set 10 | cap malheureux
# Prcessing Record 42 of Set 10 | tessalit
# Prcessing Record 43 of Set 10 | maltahohe
# Prcessing Record 44 of Set 10 | pafos
# Prcessing Record 45 of Set 10 | bama
# Prcessing Record 46 of Set 10 | urusha
# Prcessing Record 47 of Set 10 | vawkavysk
# Prcessing Record 48 of Set 10 | marang
# Prcessing Record 49 of Set 10 | jinxi
# Prcessing Record 50 of Set 10 | kupang
# Prcessing Record 1 of Set 11 | kazachinskoye
# Prcessing Record 2 of Set 11 | taguatinga
# Prcessing Record 3 of Set 11 | mogok
# Prcessing Record 4 of Set 11 | sokolovo
# Prcessing Record 5 of Set 11 | mingguang
# Prcessing Record 6 of Set 11 | novyy urgal
# Prcessing Record 7 of Set 11 | suaita
# Prcessing Record 8 of Set 11 | kargil
# Prcessing Record 9 of Set 11 | turayf
# Prcessing Record 10 of Set 11 | benjamin constant
# Prcessing Record 11 of Set 11 | la oroya
# Prcessing Record 12 of Set 11 | beira
# Prcessing Record 13 of Set 11 | pouembout
# Prcessing Record 14 of Set 11 | lata
# Prcessing Record 15 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping....
# Prcessing Record 16 of Set 11 | oktyabrskoye
# Prcessing Record 17 of Set 11 | iguatu
# Prcessing Record 18 of Set 11 | hervey bay
# Prcessing Record 19 of Set 11 | goundi
# Prcessing Record 20 of Set 11 | asau
# Prcessing Record 21 of Set 11 | lamar
# Prcessing Record 22 of Set 11 | lensk
# Prcessing Record 23 of Set 11 | senno
# Prcessing Record 24 of Set 11 | tabiauea
# City not found. Skipping....
# Prcessing Record 25 of Set 11 | kysyl-syr
# Prcessing Record 26 of Set 11 | karlshamn
# Prcessing Record 27 of Set 11 | san carlos del zulia
# Prcessing Record 28 of Set 11 | assomada
# Prcessing Record 29 of Set 11 | parita
# Prcessing Record 30 of Set 11 | turukhansk
# Prcessing Record 31 of Set 11 | lishui
# Prcessing Record 32 of Set 11 | north platte
# Prcessing Record 33 of Set 11 | vanderhoof
# Prcessing Record 34 of Set 11 | encruzilhada do sul
# Prcessing Record 35 of Set 11 | zapolyarnyy
# Prcessing Record 36 of Set 11 | wadi maliz
# Prcessing Record 37 of Set 11 | ajdabiya
# Prcessing Record 38 of Set 11 | chake chake
# Prcessing Record 39 of Set 11 | aden
# Prcessing Record 40 of Set 11 | sisimiut
# Prcessing Record 41 of Set 11 | matveyevka
# Prcessing Record 42 of Set 11 | mount vernon
# Prcessing Record 43 of Set 11 | port macquarie
# Prcessing Record 44 of Set 11 | podgorica
# Prcessing Record 45 of Set 11 | guanica
# Prcessing Record 46 of Set 11 | qaqortoq
# Prcessing Record 47 of Set 11 | khasan
# Prcessing Record 48 of Set 11 | nevel
# Prcessing Record 49 of Set 11 | soyo
# Prcessing Record 50 of Set 11 | mount gambier
# Prcessing Record 1 of Set 12 | auki
# Prcessing Record 2 of Set 12 | dukat
# Prcessing Record 3 of Set 12 | yurty
# Prcessing Record 4 of Set 12 | salalah
# Prcessing Record 5 of Set 12 | klaksvik
# Prcessing Record 6 of Set 12 | governador valadares
# Prcessing Record 7 of Set 12 | vicuna
# Prcessing Record 8 of Set 12 | tarakan
# Prcessing Record 9 of Set 12 | maldonado
# Prcessing Record 10 of Set 12 | tarare
# Prcessing Record 11 of Set 12 | dujuma
# City not found. Skipping....
# Prcessing Record 12 of Set 12 | neiafu
# Prcessing Record 13 of Set 12 | krylovskaya
# Prcessing Record 14 of Set 12 | lumphat
# Prcessing Record 15 of Set 12 | port moresby
# Prcessing Record 16 of Set 12 | pathein
# Prcessing Record 17 of Set 12 | toliary
# City not found. Skipping....
# Prcessing Record 18 of Set 12 | szydlowiec
# Prcessing Record 19 of Set 12 | chapeco
# Prcessing Record 20 of Set 12 | verkh-usugli
# Prcessing Record 21 of Set 12 | hvolsvollur
# Prcessing Record 22 of Set 12 | behbahan
# Prcessing Record 23 of Set 12 | kourou
# Prcessing Record 24 of Set 12 | ust-maya
# Prcessing Record 25 of Set 12 | aquiraz
# Prcessing Record 26 of Set 12 | ankazoabo
# Prcessing Record 27 of Set 12 | olga
# Prcessing Record 28 of Set 12 | verkhnevilyuysk
# Prcessing Record 29 of Set 12 | tostamaa
# City not found. Skipping....
# Prcessing Record 30 of Set 12 | wilmington
# Prcessing Record 31 of Set 12 | kokkola
# Prcessing Record 32 of Set 12 | nouadhibou
# Prcessing Record 33 of Set 12 | koluszki
# Prcessing Record 34 of Set 12 | bilibino
# Prcessing Record 35 of Set 12 | matara
# Prcessing Record 36 of Set 12 | severo-yeniseyskiy
# Prcessing Record 37 of Set 12 | alekseyevsk
# Prcessing Record 38 of Set 12 | coihueco
# Prcessing Record 39 of Set 12 | ust-kamchatsk
# City not found. Skipping....
# Prcessing Record 40 of Set 12 | russell
# Prcessing Record 41 of Set 12 | hargeysa
# Prcessing Record 42 of Set 12 | tayoltita
# Prcessing Record 43 of Set 12 | rampura
# Prcessing Record 44 of Set 12 | port blair
# Prcessing Record 45 of Set 12 | marsh harbour
# Prcessing Record 46 of Set 12 | kakinada
# Prcessing Record 47 of Set 12 | vagur
# Prcessing Record 48 of Set 12 | lolua
# City not found. Skipping....
# Prcessing Record 49 of Set 12 | arica
# Prcessing Record 50 of Set 12 | atasu
# Prcessing Record 1 of Set 13 | peniche
# Prcessing Record 2 of Set 13 | itapora
# Prcessing Record 3 of Set 13 | inderborskiy
# City not found. Skipping....
# Prcessing Record 4 of Set 13 | artyk
# City not found. Skipping....
# Prcessing Record 5 of Set 13 | laguna
# Prcessing Record 6 of Set 13 | college
# Prcessing Record 7 of Set 13 | agadez
# Prcessing Record 8 of Set 13 | kawana waters
# City not found. Skipping....
# Prcessing Record 9 of Set 13 | wana
# Prcessing Record 10 of Set 13 | mabaruma
# Prcessing Record 11 of Set 13 | black river
# Prcessing Record 12 of Set 13 | lianzhou
# Prcessing Record 13 of Set 13 | coihaique
# Prcessing Record 14 of Set 13 | labutta
# City not found. Skipping....
# Prcessing Record 15 of Set 13 | laguna de perlas
# Prcessing Record 16 of Set 13 | wageningen
# Prcessing Record 17 of Set 13 | lekoni
# Prcessing Record 18 of Set 13 | killam
# Prcessing Record 19 of Set 13 | general roca
# Prcessing Record 20 of Set 13 | sumenep
# Prcessing Record 21 of Set 13 | cozumel
# Prcessing Record 22 of Set 13 | rio gallegos
# Prcessing Record 23 of Set 13 | bajo baudo
# City not found. Skipping....
# Prcessing Record 24 of Set 13 | guarapari
# Prcessing Record 25 of Set 13 | daru
# Prcessing Record 26 of Set 13 | eureka
# Prcessing Record 27 of Set 13 | saint-paul
# Prcessing Record 28 of Set 13 | pangai
# Prcessing Record 29 of Set 13 | georgiyevka
# Prcessing Record 30 of Set 13 | tsaratanana
# Prcessing Record 31 of Set 13 | blythe
# Prcessing Record 32 of Set 13 | nizhneudinsk
# Prcessing Record 33 of Set 13 | visnes
# Prcessing Record 34 of Set 13 | azrow
# City not found. Skipping....
# Prcessing Record 35 of Set 13 | oranjemund
# Prcessing Record 36 of Set 13 | samokov
# Prcessing Record 37 of Set 13 | ormara
# Prcessing Record 38 of Set 13 | ikalamavony
# Prcessing Record 39 of Set 13 | barguzin
# Prcessing Record 40 of Set 13 | morant bay
# Prcessing Record 41 of Set 13 | aklavik
# Prcessing Record 42 of Set 13 | lagos
# Prcessing Record 43 of Set 13 | andevoranto
# City not found. Skipping....
# Prcessing Record 44 of Set 13 | sorvag
# City not found. Skipping....
# Prcessing Record 45 of Set 13 | ugoofaaru
# Prcessing Record 46 of Set 13 | presque isle
# Prcessing Record 47 of Set 13 | boyolangu
# Prcessing Record 48 of Set 13 | esmeraldas
# Prcessing Record 49 of Set 13 | bani walid
# Prcessing Record 50 of Set 13 | san martin
# Prcessing Record 1 of Set 14 | dalby
# Prcessing Record 2 of Set 14 | solnechnyy
# Prcessing Record 3 of Set 14 | vila
# Prcessing Record 4 of Set 14 | marsa matruh
# Prcessing Record 5 of Set 14 | zachagansk
# City not found. Skipping....
# Prcessing Record 6 of Set 14 | uzhur
# Prcessing Record 7 of Set 14 | adrar
# Prcessing Record 8 of Set 14 | tailai
# Prcessing Record 9 of Set 14 | nizhniy odes
# Prcessing Record 10 of Set 14 | gurskoye
# City not found. Skipping....
# Prcessing Record 11 of Set 14 | wajima
# Prcessing Record 12 of Set 14 | tautira
# Prcessing Record 13 of Set 14 | tabou
# Prcessing Record 14 of Set 14 | petropavlovsk-kamchatskiy
# Prcessing Record 15 of Set 14 | le vauclin
# Prcessing Record 16 of Set 14 | essex
# Prcessing Record 17 of Set 14 | rungata
# City not found. Skipping....
# Prcessing Record 18 of Set 14 | mineiros
# Prcessing Record 19 of Set 14 | lincoln
# Prcessing Record 20 of Set 14 | lucea
# Prcessing Record 21 of Set 14 | afsin
# Prcessing Record 22 of Set 14 | lengnau
# Prcessing Record 23 of Set 14 | hailar
# Prcessing Record 24 of Set 14 | kuche
# City not found. Skipping....
# Prcessing Record 25 of Set 14 | gisborne
# Prcessing Record 26 of Set 14 | lewistown
# Prcessing Record 27 of Set 14 | manzil jamil
# City not found. Skipping....
# Prcessing Record 28 of Set 14 | vestbygda
# City not found. Skipping....
# Prcessing Record 29 of Set 14 | velasco ibarra
# Prcessing Record 30 of Set 14 | deputatskiy
# Prcessing Record 31 of Set 14 | aqtobe
# Prcessing Record 32 of Set 14 | scarborough
# Prcessing Record 33 of Set 14 | do gonbadan
# Prcessing Record 34 of Set 14 | kitami
# Prcessing Record 35 of Set 14 | kumano
# Prcessing Record 36 of Set 14 | seoul
# Prcessing Record 37 of Set 14 | ergani
# Prcessing Record 38 of Set 14 | yulara
# Prcessing Record 39 of Set 14 | praia
# Prcessing Record 40 of Set 14 | ndele
# Prcessing Record 41 of Set 14 | nuuk
# Prcessing Record 42 of Set 14 | kikwit
# Prcessing Record 43 of Set 14 | atocha
# Prcessing Record 44 of Set 14 | iralaya
# Prcessing Record 45 of Set 14 | emerald
# Prcessing Record 46 of Set 14 | ladario
# Prcessing Record 47 of Set 14 | temaraia
# City not found. Skipping....
# Prcessing Record 48 of Set 14 | katobu
# Prcessing Record 49 of Set 14 | luwuk
# Prcessing Record 50 of Set 14 | kozhva
# Prcessing Record 1 of Set 15 | contai
# Prcessing Record 2 of Set 15 | shuya
# Prcessing Record 3 of Set 15 | hihifo
# City not found. Skipping....
# Prcessing Record 4 of Set 15 | yaan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Creating the city data dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Mataura      NZ -46.1927  168.8643     74.19        37
# 1               Tucuman      AR -26.8241  -65.2226     68.00        77
# 2              Meulaboh      ID   4.1363   96.1285     76.62        93
# 3              Aberdeen      GB  57.1437   -2.0981     45.50        77
# 4                 Tiksi      RU  71.6872  128.8694     13.26        78
# 5               Ganzhou      CN  28.8184  115.4327     49.26        33
# 6  Vila Franca Do Campo      PT  37.7167  -25.4333     70.20        74
# 7              Denpasar      ID  -8.6500  115.2167     85.71        79
# 8               Rikitea      PF -23.1203 -134.9692     74.97        78
# 9              Altamira      BR  -3.2033  -52.2064     76.05        83
#
#    Cloudiness  Wind Speed Current Description
# 0         100        2.35     overcast clouds
# 1           0        3.44           clear sky
# 2         100        8.37     overcast clouds
# 3          95        5.75     overcast clouds
# 4         100       22.66     overcast clouds
# 5           6        7.92           clear sky
# 6          34       11.68    scattered clouds
# 7          40        5.75    scattered clouds
# 8         100       13.85       moderate rain
# 9         100        2.46     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_data into a csv 
city_data_df.to_csv(output_data_file, index_label = "City_ID")
